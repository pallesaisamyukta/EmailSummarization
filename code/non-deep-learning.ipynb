# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import json
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\samyukta\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\samyukta\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\samyukta\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# Specify the path to your JSON file
file_path = "../data/output/data.json"

# Open the JSON file and load its contents
with open(file_path, 'r') as file:
    email_list = json.load(file)

# %%
# Define a function for preprocessing with lemmatization
def preprocess_with_lemmatization(text):
    # Tokenize the text into words
    words = word_tokenize(text)
    
    # Remove stop words
    stop_words = set(stopwords.words("english"))
    words = [word for word in words if word.lower() not in stop_words]
    
    # Lemmatize the words
    lemmatizer = WordNetLemmatizer()
    lemmatized_words = [lemmatizer.lemmatize(word, pos='v') for word in words]  # Lemmatize verbs
    
    # Join the lemmatized words back into text
    preprocessed_text = " ".join(lemmatized_words)
    
    return preprocessed_text

# %%
# Preprocess the emails using lemmatization
preprocessed_emails = [preprocess_with_lemmatization(email) for email in email_list]

# %%
# Calculating TF-IDF for each email
generated_list = []
for i in range(len(preprocessed_emails)):
    tfidf_vectorizer = TfidfVectorizer()
    tfidf_matrix = tfidf_vectorizer.fit_transform([preprocessed_emails[i],])

    # Compute cosine similarity between sentences
    cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)

    # Create sentence scores based on TF-IDF scores
    sentence_scores = cosine_sim[0]

    # Sort the sentence scores
    sorted_indices = np.argsort(sentence_scores)

    # Number of sentences in the summary
    num_sentences = 5

    # Extract top sentences as the summary
    top_sentence_indices = sorted_indices[-num_sentences:]
    # Extract top sentences using the sorted indices
    summary = ' '.join([preprocessed_emails[i].split('.')[idx] for idx in top_sentence_indices])

    # Print the original document and the summary
    print("Original Document:")
    print(email_list[i])

    print("\nSummarized Text:")
    generated_list.append(summary)
    print(summary)
# Out:
# Original Document:
# Uncover your surprise springtime savings today!
#
# To view the html graphic version of this message, please copy and paste the link below into your browser:
# http://l.em.disneydebit.com/rts/go2.aspx?t=371661&tp=i-1NGB-DG-7u6-rkzO5-1n-318pE-1c-rdwep-lA6RAbMS3B-IvqO&pi=8Y640LqX2Icv1QAy0zTeQHle-81TYwfgOvYMocKnDJQ&x=5778bf70154f43651af115ca8b80e4ff&hp2=25b68808335e2409b8306afbecd8428393cb5594e9eaf2f26580edfc99913245
#
# Offer made by Disney. JPMorgan Chase Bank, N.A. and its affiliates are not affiliates of Disney and are not responsible for offer fulfillment.
#
# For all inquiries regarding the Disney Debit Card, please visit DisneyDebit.com.
# http://l.em.disneydebit.com/rts/go2.aspx?t=371662&tp=i-1NGB-DG-7u6-rkzO5-1n-318pE-1c-rdwep-lA6RAbMS3B-IvqO&pi=8Y640LqX2Icv1QAy0zTeQHle-81TYwfgOvYMocKnDJQ&x=20240301&hp2=94a8c989e287e34057a32357d2f311f7dd9dc5346b88b69a5a455d77ca26c532
#
# This email was sent to: pallesaisamyukta@gmail.com
#
# Please do not reply to this email as this address is not monitored.
#
# This email is from Disney Rewards, LLC, PO Box 3786, Anaheim, CA 92803-3786. If, as a Disney Visa Debit Cardmember, you do not wish to receive from Disney Rewards any future emails about special Cardmember offers, please click here.
# http://l.em.disneydebit.com/rts/go2.aspx?t=371663&tp=i-1NGB-DG-7u6-rkzO5-1n-318pE-1c-rdwep-lA6RAbMS3B-IvqO&pi=8Y640LqX2Icv1QAy0zTeQHle-81TYwfgOvYMocKnDJQ&x=pallesaisamyukta@gmail.com&hp2=c6d8af806d55b4b0fa2508b788b8caf7b2172432b6d3c0134ab8cb24c28e1c70
#
# Deposit and credit card products provided by JPMorgan Chase Bank, N.A. Member FDIC
# (C) 2024 JPMorgan Chase & Co.
#
# (C) 2024 Disney and its related entities.
#
#
#
#
# Summarized Text:
# Uncover surprise springtime save today ! view html graphic version message , please copy paste link browser : http : //l
# Original Document:
# Hey Sai,
#
# February is over! Visit Splitwise to see your current debts and IOUs and to settle up with your friends: https://www.splitwise.com/applinks/open
#
# Any comments, thoughts, or suggestions? Hit reply and let us know.
#
# Have a great day!
# -The Splitwise Team
#
#
# Splitwise, Inc.
# 150 Union St, Suite 606
# Providence, RI 02903 USA
#
# unsubscribe https://emails.splitwise.com/asm/unsubscribe/global/?user_id=256585&data=w--kxavT_j4jkm3m6M8I613ZcAsoh4S_6r00gvICKcRoMDAwdTAwMF2uLA4NtYPMN4kzC39xIeQaCOKJYolWn_MEPVKpVY1A9Q_vhJeU1fI-ZZrkzbuQl5V6m9xW-Mml6Cp9LLCF4yXu99u9huoiwIQomi6aTl2H7f9P8aAxJIws2tep-wmdrr_f_jDEDUuIy_10vT4MSwMJOqCwNqYk-VTMVx1_2hp9ByFg4eu1ktWFYvU3fDguhwYxdmitcDyBJ_tPvHjGFbOCrBNh1WiECULuOjxo0fcVZX7EFf28_UIkyT-0pPj_P9uoBgoBMNKfsaEI4WEq_6QMjBQtX-Zge6WHeehapxd5RhRZYnyaBVG2OhAJ6e4WPJZf_sJV40nbfvVaCYAVf2B6U3G_oT3uOJ2dbTTkylkIlRoB1YaP7CNaybKlJYA_qV3-KghLvYZwGmTEtS3PKx4XXrG9Ov8sKQT7OPT024e4B3OUMXzhlswSdXAbbNQygA==
#
# Summarized Text:
# Hey Sai , February ! Visit Splitwise see current debts IOUs settle friends : https : //www
# Original Document:
# Kaggle
#
#
#
#
#
#
#
#
# Hi Sai Samyukta Palle,
#
# It's Leap Day, and to celebrate, Google Cloud Next is offering 65% off with
# promo code NEXT699LEAP today!* 🙌 The conference is happening in Las Vegas
# on April 9 - 11 and is packed with ML and AI programming, including a lot
# of amazing Kaggle-focused content.
#
#
#
#
#
# For example:
#
#
# Workshops with Kaggle Grandmasters like David Austen (recent 1st place
# winner in our LLM – Detect AI Generated Text competition) & Ruchi Bhatia
# (youngest 3x Kaggle Grandmaster)
# Sessions with prominent researchers who've launched groundbreaking Kaggle
# competitions like Rhiju Das (Stanford professor behind the Ribonanza RNA
# Folding competition & COVID-19 mRNA Vaccine Degradation Prediction
# competition)
# AMA with the Kaggle team including our CEO, D. Sculley
# In-person Kaggle competition with fun prizes 🎉
#
#
#
# Register Here
#
#
#
# A full lineup of all the Kaggle-focused magic at the event is coming your
# way soon! We really hope to see you there.
#
# The Kaggle Team
#
#
#
# *Space is limited, and this price is only valid with the promotional code
# through 11:59 PM PT on February 29, 2024, or until sold out.
#
#
#
#
# Kaggle, Inc 1600 Amphitheatre Pkwy Mountain View, CA 94043
#
# This email was sent to pallesaisamyukta@gmail.com because you indicated
# that you'd like to receive news and updates about Kaggle. If you don't want
# to receive these emails in the future, please unsubscribe here. You can
# also change your preferences on your account's profile page by logging in
# at kaggle.com.
#
#
#
#
#
#
# Summarized Text:
# Kaggle Hi Sai Samyukta Palle , 's Leap Day , celebrate , Google Cloud Next offer 65 % promo code NEXT699LEAP today ! * 🙌 conference happen Las Vegas April 9 - 11 pack ML AI program , include lot amaze Kaggle-focused content
# Original Document:
# Kaggle
#
#
#
#
#
#
#
#
# Hi Sai Samyukta Palle,
#
# We've had a number of trending models added to Kaggle and encourage you to
# check them out!
#
#
#
#
#
#
# Gemma
# Publisher: Google
# Gemma, a family of lightweight, state-of-the-art open models built
# from the research and technology that Google used to create the
# Gemini models. Model variations include Keras, JAX, PyTorch,
# Transformers, and many more.
#
#
#
#
#
#
# Phi
# Publisher: Microsoft
# Small language models (SLMs) from the Machine Learning Foundations
# team at Microsoft Research.
#
#
#
#
#
#
# Aya
# Publisher: Cohere For AI
# The Aya model is a massively multilingual generative language model
# that follows instructions in 101 languages.
#
#
#
#
#
# Try these models out, share notebooks that use the models, and upvote the
# ones you like. We're excited to see what you will build.
#
# Thanks for being part of Kaggle's community!
#
# The Kaggle Team
#
#
#
# Kaggle, Inc 1600 Amphitheatre Pkwy Mountain View, CA 94043
#
# This email was sent to pallesaisamyukta@gmail.com because you indicated
# that you'd like to receive news and updates about Kaggle. If you don't want
# to receive these emails in the future, please unsubscribe here. You can
# also change your preferences on your account's profile page by logging in
# at kaggle.com
#
#
#
#
#
#
# Summarized Text:
# Kaggle Hi Sai Samyukta Palle , 've number trend model add Kaggle encourage check ! Gemma Publisher : Google Gemma , family lightweight , state-of-the-art open model build research technology Google use create Gemini model
# Original Document:
# We now support fine-tuning for `gpt-3.5-turbo-0125`, our latest GPT-3.5 Turbo model.
#
# OpenAI Logo ( https://openai.com/ )
#
# Hi there,
#
# We now support fine-tuning for `gpt-3.5-turbo-0125`, our latest GPT-3.5 Turbo model. It’s available alongside other models for fine-tuning, including `gpt-3.5-turbo-1106`, `gpt-3.5-turbo-0613`, `babbage-002`, and `davinci-002`.
#
# To get started, check out the fine-tuning API docs ( https://platform.openai.com/docs/guides/fine-tuning ). If you have questions, reach out in the OpenAI developer forum ( https://community.openai.com/ ). For the latest updates, follow @OpenAIDevs ( https://twitter.com/OpenAIDevs ) on X.
#
# Happy building!
# The OpenAI Team
#
# OpenAI
#
# 548 Market Street, PMB 97273 , San Francisco , CA 94104-5401
#
ZGRPicdeuo_PcG76C97cRkvFVhb4GhzJmqm6G9boAf8xfYXmF_z9_gJWDzt6zBXpZJiR0YHNSlYeSua7cwIJBFefg3l49qhr1TyzkOsTYlvSvBAUdIqhjNKZI6V4Ps36UtCEjvgOk9qFxgt_5reCA-9XSRKodrwCDGDvSJMSjDzlpsch8hj6F3NFPsMgbANZZopZk-eQeDKlACLLVcRx8Er3i9kSK5cDyO30U_iKhIxuW4Q7rlQDH_yszlc4Ft4HlIwe-3IOvW6NtDFrYWPYMOPF1GwqbpVEv_UWp8F04B3qbDfgEfku2YEZle1TYZFhXyhyRdZs1kqyvfZVoIhS_RkTk1YlCTj7CAKdhvEXgnjwSn9_3FIq8RTNqG7X2GVp1GsbyjeW0Lcse9glAuj_1XU5T4Q4pnsON7jYlZ8hZOdozbKs9yV9-y2UVvy3Z8-0jdTYI-NoongfGf-bgYOaJIk9KVRlsujX1lzU4TkbykZ23ldBKEabbP02UylstvBcKoBR7qsir1FCeZttIex-u4Pi5pNi_rmC8pci341YuQmS_1Y1bi1rd1oBPvLQ1dH6hpp7YtDOWFhnsGgeM2L5wiuWFJQccHbq_XYboGyYyJUTHYZho2icG6iTg5_oYj9-7ytS-uEMq_Tt48xKfHndXz0cbwUD-Wv3q_UEeUfNaFxWrhdJlJ_G133ia-DPh9M_zcFbyfXNPZVMyrBXvYjezAiMCogH7uA1KRW3f4DDlZ4DVA6lE7613Mkp8k2oEZ4Ey7KM1T6uWT2wAtOj8y7XXQzLIEgPKBNIlO4TsLAcXbXHWw_Zaw0p1i_-7FSyg-1XuHtS5BAcsGyYM8WZC8OoVdqOcuF6wfLuK4gI_d5ZqIWQNkRmV4IzM5KkHbDlq-WgBa4tIXwlFrqjV9w6IATZEKdulTgU )
#
# Summarized Text:
# support fine-tune ` gpt-3
# Original Document:
# We’re excited to help you tell
# your next story96 * *   * {
# box-sizing: border-box; } body { margin: 0; padding: 0; }
# a[x-apple-data-detectors] { color: inherit !important;
# text-decoration: inherit !important; } #MessageViewBody a {
# color: inherit; text-decoration: none; } p { line-height:
# inherit; } .desktop_hide, .desktop_hide table { mso-hide: all;
# display: none; max-height: 0; overflow: hidden; } .image_block
# img + div { display: none; } @media (max-width: 610px) { .row-1
# .column-1 .block-1.image_block img { display: inline-block
# !important; } .image_block img.big, .row-content { width: 100%
# !important; } .mobile_hide, .row .side { display: none; } .stack
# .column { width: 100%; display: block; } .mobile_hide {
# min-height: 0; max-height: 0; max-width: 0; overflow: hidden;
# font-size: 0; } .desktop_hide, .desktop_hide table { display:
# table !important; max-height: none !important; } .row-2 .column-1
# .block-1.heading_block td.pad { padding: 0 35px !important; }
# .row-2 .column-1 .block-1.heading_block h1, .row-2 .column-1
# .block-3.heading_block h1, .row-3 .column-1
# .block-1.paragraph_block td.pad > div { font-size: 24px
# !important; } .row-1 .column-1 .block-1.image_block td.pad {
# padding: 0 !important; } .row-1 .column-1 .block-1.image_block
# .alignment, .row-6 .column-2 .block-1.paragraph_block td.pad >
# div { text-align: center !important; } .row-3 .column-1
# .block-1.paragraph_block td.pad { padding: 5px 10px !important; }
# .row-2 .column-1 .block-4.paragraph_block td.pad > div {
# font-size: 20px !important; } .row-2 .column-1
# .block-4.paragraph_block td.pad { padding: 5px 60px 10px
# !important; } .row-4 .column-1 .block-2.list_block td.pad, .row-4
# .column-1 .block-4.list_block td.pad, .row-4 .column-1
# .block-6.list_block td.pad, .row-4 .column-1 .block-8.list_block
# td.pad { padding: 0 40px 20px !important; } .row-4 .column-1
# .block-2.list_block ul, .row-4 .column-1 .block-4.list_block ul,
# .row-4 .column-1 .block-6.list_block ul, .row-4 .column-1
# .block-8.list_block ul { font-size: 20px !important; line-height:
# auto !important; } .row-6 .column-1 .block-1.image_block td.pad {
# padding: 10px 5px 0 0 !important; } .row-2 .column-1 { padding:
# 20px 0 !important; } }                  Image
#
# ********
# Welcome👋
# ********
#
# Image
#
# *****************************************************************
#
# *****************************************************************
# Sai samyukta, it's time to make compelling
# video content.
# *****************************************************************
#
#
# Welcome to the Clipchamp community. Our goal is to
# simply empower you to make great video content.Create a video( https://ablink.info.clipchamp.com/ls/click?upn=u001.NjeJ2FfTWkrXGdob09mHCgYQAz6uv2jkG8uIqnV27yFwVd0HCcSsdkd041WNaZuyN789_s3HYpfmBYRDBdgh7MjQYVcL0e-2Bt4aN6YJv-2FXYOdW3-2F5lb8irITj4fhCQTPp8DwORHRK2RjkhEisJGGLCvBj3o1ZpkWQGnKFv9BlMExmCD0ZrB0zktCudeMRUbyVTxoqjIAk-2BmoIY6t-2FH7K2aIGuurs6CSIACNaZrP-2BsgmPLc-2FjN-2BHq06kxrD43D-2BCXuaS-2FUpAxZQJ5s-2BA7Wou5yWKC6NEssAnsSqb-2BIISUCf6Vamyvev7rEfTnhkanj-2Fk36hO7fjSyPgdE1Krqd3WQxRgzNKiZmWDLmZR8x-2F39hibGJwYx-2BsjMsNtE6V-2FfrlJj7xg5DkDgjusUUT7-2FF-2FR0AlVEaVDgMV3ck49RHN57MnE1x0XIIFJ7cUD3YV-2FbeF-2F0XUCfSpaNl2OXttReUwP6xr8Rz7-2B3LbFErU0kOSJT5HaciMriffF0YJXBZHhYh-2By36K-2FLRZ7TkvZDfmcP2WUIwUNSRXxZ-2FolaXJ9LiBXsQBfB-2Btk7MwnVYef70jNRBZrMLH4YIE2INH7zjhgSqzg2ZZpAJ1KOVE8YqcWPLVFegHOM2S7WpaxZukHZ9m-2BdAYMzQUX6c2A0JcUsKnxv2627b-2BxPfPoHf2APR8-2Btd8-2B3ca-2F1IRxjsj7dLUMTULk7gJ0nD-2BIsiwjOMK6lJmRwZv-2Fc6xmQGE8ZDMP8FSq1BteIeODscXKxOLnBIdaeOtyWxIeT9RdtGJevoFPxx0cQJ5Ln5X1KwONw9886Yr-2BkH31HXjyr7t9CuXQh9gUN0BWWWp1ywtUk1-2B )You don't
# need to know everything to get started.
#
# Move ➡️
#
# #list-r3c0m1 ul { margin: 0 !important; padding: 0
# !important; } #list-r3c0m1 ul li { mso-special-format: bullet; }
# #list-r3c0m1 .levelOne li { margin-top: 0 !important; }
# #list-r3c0m1 .levelOne { margin-left: -20px !important; }
# #list-r3c0m1 .levelTwo li { margin-top: 0 !important; }
# #list-r3c0m1 .levelTwo { margin-left: 20px !important; }
# #list-r3c0m1 .levelThree li { margin-top: 0 !important; }
# #list-r3c0m1 .levelThree { margin-left: 60px !important; }
# #list-r3c0m1 .levelFour li { margin-top: 0 !important; }
# #list-r3c0m1 .levelFour { margin-left: 100px !important; }
# #list-r3c0m1 .levelFive li { margin-top: 0 !important; }
# #list-r3c0m1 .levelFive { margin-left: 140px !important; }
# #list-r3c0m1 .levelSix li { margin-top: 0 !important; }
# #list-r3c0m1 .levelSix { margin-left: 180px !important; }
# #list-r3c0m1 .levelSeven li { margin-top: 0 !important; }
# #list-r3c0m1 .levelSeven { margin-left: 220px !important; }
# * Place your cursor over any video in your timeline
# * Hold down the left mouse button and drag the clip to move it
# Trim ✂️
#
# #list-r3c0m3 ul { margin: 0 !important; padding: 0
# !important; } #list-r3c0m3 ul li { mso-special-format: bullet; }
# #list-r3c0m3 .levelOne li { margin-top: 0 !important; }
# #list-r3c0m3 .levelOne { margin-left: -20px !important; }
# #list-r3c0m3 .levelTwo li { margin-top: 0 !important; }
# #list-r3c0m3 .levelTwo { margin-left: 20px !important; }
# #list-r3c0m3 .levelThree li { margin-top: 0 !important; }
# #list-r3c0m3 .levelThree { margin-left: 60px !important; }
# #list-r3c0m3 .levelFour li { margin-top: 0 !important; }
# #list-r3c0m3 .levelFour { margin-left: 100px !important; }
# #list-r3c0m3 .levelFive li { margin-top: 0 !important; }
# #list-r3c0m3 .levelFive { margin-left: 140px !important; }
# #list-r3c0m3 .levelSix li { margin-top: 0 !important; }
# #list-r3c0m3 .levelSix { margin-left: 180px !important; }
# #list-r3c0m3 .levelSeven li { margin-top: 0 !important; }
# #list-r3c0m3 .levelSeven { margin-left: 220px !important; }
# * Drag and drop your video onto the timeline
# * Select your video and move the green sidebars of the clip left
# and right to trim your video
# Add an asset ➕
#
# #list-r3c0m5 ul { margin: 0 !important; padding: 0
# !important; } #list-r3c0m5 ul li { mso-special-format: bullet; }
# #list-r3c0m5 .levelOne li { margin-top: 0 !important; }
# #list-r3c0m5 .levelOne { margin-left: -20px !important; }
# #list-r3c0m5 .levelTwo li { margin-top: 0 !important; }
# #list-r3c0m5 .levelTwo { margin-left: 20px !important; }
# #list-r3c0m5 .levelThree li { margin-top: 0 !important; }
# #list-r3c0m5 .levelThree { margin-left: 60px !important; }
# #list-r3c0m5 .levelFour li { margin-top: 0 !important; }
# #list-r3c0m5 .levelFour { margin-left: 100px !important; }
# #list-r3c0m5 .levelFive li { margin-top: 0 !important; }
# #list-r3c0m5 .levelFive { margin-left: 140px !important; }
# #list-r3c0m5 .levelSix li { margin-top: 0 !important; }
# #list-r3c0m5 .levelSix { margin-left: 180px !important; }
# #list-r3c0m5 .levelSeven li { margin-top: 0 !important; }
# #list-r3c0m5 .levelSeven { margin-left: 220px !important; }
# #list-r3c0m5 .levelEight li { margin-top: 0 !important; }
# #list-r3c0m5 .levelEight { margin-left: 260px !important; }
# #list-r3c0m5 .levelNine li { margin-top: 0 !important; }
# #list-r3c0m5 .levelNine { margin-left: 300px !important; }      *
# Select a type of asset such as ‘Stock video’ from the left-hand
# side bar
# * Hover over a video thumbnail you like and click the green +
# sign to add it to your timeline
# Export your video 🎬
#
# #list-r3c0m7 ul { margin: 0 !important; padding: 0
# !important; } #list-r3c0m7 ul li { mso-special-format: bullet; }
# #list-r3c0m7 .levelOne li { margin-top: 0 !important; }
# #list-r3c0m7 .levelOne { margin-left: -20px !important; }
# #list-r3c0m7 .levelTwo li { margin-top: 0 !important; }
# #list-r3c0m7 .levelTwo { margin-left: 20px !important; }
# #list-r3c0m7 .levelThree li { margin-top: 0 !important; }
# #list-r3c0m7 .levelThree { margin-left: 60px !important; }
# #list-r3c0m7 .levelFour li { margin-top: 0 !important; }
# #list-r3c0m7 .levelFour { margin-left: 100px !important; }
# #list-r3c0m7 .levelFive li { margin-top: 0 !important; }
# #list-r3c0m7 .levelFive { margin-left: 140px !important; }
# #list-r3c0m7 .levelSix li { margin-top: 0 !important; }
# #list-r3c0m7 .levelSix { margin-left: 180px !important; }
# #list-r3c0m7 .levelSeven li { margin-top: 0 !important; }
# #list-r3c0m7 .levelSeven { margin-left: 220px !important; }
# * Click on the 'Export' button in the top right corner of the
# editor
# * Select the video quality you would like
# * Wait for your creation to export
# * Now you can save it to your computer or immediately share it
# * And just like that, you are now a pro video editor
# * Sit back and smile 😊
# To continue getting tips, newsletters,
# promotions and recommendations from Clipchamp
#
# 👇Subscribe to Clipchamp emails(
# https://ablink.info.clipchamp.com/ls/click?upn=u001.NjeJ2FfTWkrXGdob09mHCqanHwRZKXLqdJuNSCf0Mh6rCJUNUHAvv5Un5wdOwDDnpc7jHi0TwTTzQRe7p4Cq6qlDcxXOUrAYMYudWMac4vQMVbYh57HygLdRHuWxe5eMNzeEAbCZLIdYqhOVpr3njfeH6DzRPibkRFem67nU-2BawCpgW24SVKdcU-2BjZKnIflDIZQrlFC1-2FFWMDnOviAqqi5cx1hZ3IMdlztbc7YDBJBmW1HwUwCowqF7vQVOPlnLNu0FqhgoA9WZ09PKH2yrp0OK2pL-2Be-2BZLXHNUvw-2FRxF4i25HnTfqMGSysiRoN7S3Hy2bjb9dNZbM0CQz9pdJyJ0-2Bxa0cfMZRlHyDxzaR7kCvaxfAPqUw0LtykPXN-2F4-2Bi5r-2F3DiBUTY5op0qVdF3rn8K5mfKFc5cgzaf6goF1U69FWLpozuWWbDjNtXQFleIhEqgi-2Fn-2BbS-2FlJIyJ6MEmzawqiDGufR-2BsB1EUesDVDznXkt2qjf0MBZSPPByWZiWAGOhSRocZVFy3z1Ay05PZDPx4MJF-2BiJagr4jmLla-2BwAsw6nLOsDG8TfCemrpydd1WzzGgp9hNjToMhEBRxrlnMBny7MYhteIaMBD4FCxEL1xTLhIVBmp1-2
ZsjdsfNO46Z3tAi5IX6ndFa8NtJHTUYonMS8wSpLbIMTt0sYC7khRfk3H5DSzlCiBzapD9NW-2BlOpRrohMTF-2Bx21q-2BXkmckOrk2EZ-2BaJ9K4bz-2BWMcxXqQP4v1azWeY4K2vx4fIj22s-2FtgdSHCsxnVvZfp7m4XH88iaz6Co0uOr-2FXAOb-2BF6BWmoBgu-2B8AOS0zr8zHoVqNLYYKraT6Q0QbKqVkow-3D-3DoWef_s3HYpfmBYRDBdgh7MjQYVcL0e-2Bt4aN6YJv-2FXYOdW3-2F5lb8irITj4fhCQTPp8DwORHRK2RjkhEisJGGLCvBj3o1ZpkWQGnKFv9BlMExmCD0ZrB0zktCudeMRUbyVTxoqjIAk-2BmoIY6t-2FH7K2aIGuurs6CSIACNaZrP-2BsgmPLc-2FjN-2BHq06kxrD43D-2BCXuaS-2FUpAxZQJ5s-2BA7Wou5yWKC6NEssAnsSqb-2BIISUCf6Vamyvev7rEfTnhkanj-2Fk36hO7fjSyPgdE1Krqd3WQxRgzNKiZmWDLmZR8x-2F39hibGJwYx-2BsjMsNtE6V-2FfrlJj7xg5DkDgjusUUT7-2FF-2FR0AlVEaVDgMV3ck49RHN57MnE1x0XIIFJ7cUD3YV-2FbeF-2F0XUCfSpaNl2OXttReUwP6xr8Rz7-2B3LbFErU0kOSJT5HaciMriffF0YJXBZHhYh-2By36K-2FLRZ7TkvZDfmcP2WUIwUNSRXxZ-2FolaXJ9LiBXsQBfB-2Btk7MwnVYef70jNRBZrMLH4YIE2INH7zjhgSqzg2ZZpAJ1KOVE8YqcWPLVFegHOM2S7WpaxZukHZ9m-2BdAYMzQUX6c2A0JcUsKnxv2627b-2BxPfPoHf2APR8-2Btd8-2B3ca-2F1IRxjs3zpSjljO3mtpBrvxRyWg-2BTz-2BUgKhQ02S0NlZaZGr-2Bpr-2Fev16D9CmMop7jKbpKZJ3MCpS4NU0X93BqquMZvI2uEJgjJYGQ2A-2Bx9nrtDXZycKTtRoVxrXsAa8m4of6oxNF0SJJTJut-2BLFXnwGsx3RyD )
#
# Summarized Text:
# ’ excite help tell next story96 * * * { box-sizing : border-box ; } body { margin : 0 ; pad : 0 ; } [ x-apple-data-detectors ] { color : inherit ! important ; text-decoration : inherit ! important ; } # MessageViewBody { color : inherit ; text-decoration : none ; } p { line-height : inherit ; }
# Original Document:
# Kaggle
#
#
#
#
#
#
#
#
# Hi Sai Samyukta Palle,
#
# NLP workflows increasingly involve rewriting text, but there's still a lot
# to learn about how to prompt LLMs effectively. This machine learning
# competition is designed to be a novel way to dig deeper into this problem.
#
# The challenge: recover the LLM prompt that was used to rewrite a given
# text. You'll be tested against a dataset of 1300+ original texts, each
# paired with a rewritten version from Gemma, Google's new family of open
# models.
#
#
#
#
#
# Total Prizes:
#
# $200,000
#
#
# Entry Deadline:
#
# April 9, 2024
#
#
#
#
# Learn More
#
#
#
# Best of luck,
#
# Will Lifferth
# Kaggle Data Scientist
#
#
#
# Kaggle, Inc 1600 Amphitheatre Pkwy Mountain View, CA 94043
#
# This email was sent to pallesaisamyukta@gmail.com because you indicated
# that you'd like to receive news and updates about Kaggle. If you don't want
# to receive these emails in the future, please unsubscribe here. You can
# also change your preferences on your account's profile page by logging in
# at kaggle.com.
#
#
#
#
#
#
# Summarized Text:
# Kaggle Hi Sai Samyukta Palle , NLP workflows increasingly involve rewrite text , 's still lot learn prompt LLMs effectively
# Original Document:
# ( https://elicit.com/ )
#
# Hi there,
#
# I wanted to share more tips about how to get the most out of the
# Find papers workflow. One of the features that distinguishes Elicit from other literature review tools is automatic data extraction.
#
#
#
# Once you ask a query and see some relevant papers, you can add columns to extract information across all of the papers.
#
#
#
# In a second, you can immediately see information like:
#
# • Main findings
#
# • Intervention
#
# • Outcome measured
#
# • Independent variables
#
#
#
#  And so much more!
#
#
#
# If one of our 30+ predefined columns don’t fit your needs, ask a custom question!
#
#
#
# You can click on the cell to see supporting quotes from the paper. You can open up the paper to see the quotes in the context of the paper.
#
#
#
# If the paper is open access, we get information from the full text. Otherwise, we use information from the abstract.
#
#
#
# Here are some pointers on improving results from columns ( https://support.elicit.com/en/articles/878273 ) and creating custom columns ( https://support.elicit.com/en/articles/906049 ).
#
#
#
# Let me know what you think!
#
#
#
# Juliet
#
# Customer Support at Elicit ( https://elicit.com/ )
#
# Elicit Help Center ( https://support.elicit.com/ )
#
# Elicit Tutorials ( https://www.youtube.com/@elicit-research )
#
# You are receiving this email because you signed up for Elicit ( https://elicit.com/ ), an AI research assistant. You can manage email preferences here ( http://track.customer.io/manage_subscription_preferences/dgTd9ggBAJiydJeydAGN63aXLQ_HTKFsTjzOFzY= ). To view this email in your browser, click here ( http://track.customer.io/deliveries/dgTd9ggBAJiydJeydAGN63aXLQ_HTKFsTjzOFzY= ).
#
# Summarized Text:
# ( https : //elicit
# Original Document:
# Join the world's largest association of experts on the science and technology of decision making
#
# Don't miss out on your chance to save!
#
# For a limited time, you can join the world's largest community of experts on the science and technology of decision making at ONLY $109 for a regular membership. Students join for $42.
#
# Click to Join INFORMS Today (https://email.informs.org/e3t/Ctc/ON+113/cpWSM04/VVpyfV109dRvW3Y9dBw97V7G3W4-ljtc5b11Q3N7vvr1x5TDv4W95jVnq6lZ3p5W1bQmHr1WBpsqW3t7NnT5235GSVDHxDL7zB9WMW23wm6X1_sMmmVHPHrg39h-QrW5C14L_7t6zWsW9bQZH45Cw_53W5LqTGF7wTh3jW6YVKrD6yLHl_W7_mdTt3mqFvvN8-HPb9fX-fyW5xk1yh6fXCpvVPNnZF3hr5q6W61s7HQ5xH9NlW1FjC5511sdvgW6FPk5B2l638lW7KBlzd4gsj9mW1khJ4S3GqGgqW12Njsr57g08GV45DsL4Jk9XxW6jq1wd97f4vjW2WZDDn7mJTzvN7tyf8DSzzn2W4SXLq21p5qgCW3l2qmF36_4KzW34bHwX7qH5WhW3m4Rly2kFKwqW336wQw7lHVnCW8cnC0m3X6vRfW7tMx-b2w-rYHVdvWwg98bG9kN5SsYDMzXCK-W131M0l4nRRcMN3MJCTYDwgHHW8Zkdf46Yyp8LW3cm4vC1_45cMW2kJJlc97pvYJW8qrkpj3qP36KW7R_6VQ2q9bpJW8KjdV_98MJRGW3QsLmh2WVRsSW3mc5t64Qzb89W8rJkBQ5W13M6W2bGRjz5JhjrSW3FykFG166JL1W125YXZ6gkYx4f8Xk85P04 )
#
# Decorating & DIY
#
# How to Make a Bookshelf Room Divider
#
# https://click.message.rentpath.com/?qs=5b1d31dd892a308ef32ce31af75ed7867474bd295e6f76f4e07125d43738b5f579fcb724a3500c5e2754ea94bccc5cfa019b7c4209327ede1ed235ffff590731
# Read More
#
#
#
#  https://click.message.rentpath.com/?qs=5b1d31dd892a308e8f297cdb6072fec80c5be2b4936eecf41c51e46e5201617d463594b76cec99e6341051820dac4043bde16f3e0509078c02930bf435ab5680
#
# Apartment Living
#
# Green Leases: How They Can Benefit You As a Renter
#
# https://click.message.rentpath.com/?qs=5b1d31dd892a308e0b1c47a782257183be9d92208546c21ac07d6873a18915c3975a35493019f80d226ab8cbc5273871ff9d377a4f4532ec4f6a5d5809f62915
# Read More
#
#
#
#  https://click.message.rentpath.com/?qs=5b1d31dd892a308e5696d3dce4779878f90e19262f17192a4575a5cd80bda2d2f3194db5dfcd53a701193ba1db4dd01684ada04b2ffc179607fcb0f8fbfd346e
#
# Pets
#
# The Best Dog Toys for Your Apartment
#
# https://click.message.rentpath.com/?qs=5b1d31dd892a308e73eb21f809f1e46c5f999041514931f18c1baf55b7d43be5e73585f054e3017f2ea9814328a1a0c4c0b447b79deca12b5c01a28cb171a36e
# Read More
#
#
#
#  https://click.message.rentpath.com/?qs=5b1d31dd892a308eb2ba75f745ad8e458307017f89bcbb61e0c8c47dac585f86c5ef84d2a5e77f5f7473da63865ebba4cf6e67347f7fe0881c7f854590234147
#
# Roommates
#
# Managing Finances When You Move in with a Partner
#
# https://click.message.rentpath.com/?qs=5b1d31dd892a308efcb28b9c12413db25c371f08fc00c8c5497edba6027de76a8f0fb3be44b14e0207e10a95c7b272a04bc632a079bcec78372ec0316519158e
# Read More
#
#
#
#  https://click.message.rentpath.com/?qs=a126a0c983aa9cc93f5fab3a6b6ecf663cf4987b0f1312619f5338fdd3e06c2c01276f76e7957bb96e9ea8cde6e4fa04da1232d78aaaef5bbe47faf048314b86
#
# Money & Finance
#
# What Does an Admin Fee Cover in Your Apartment Application?
#
# https://click.message.rentpath.com/?qs=a126a0c983aa9cc98a387a5e08c16f316c6a6ff7157f70e117a8fc10cae9ff0f8c5cf6e6f1b8c67ae9f098b4ba6bb6fe06887590df3f11f22ab9ff73789f22c7
# Read More
#
#
#
#  https://click.message.rentpath.com/?qs=a126a0c983aa9cc98581875c90ccdefc3c0182d136c798545bddc7508a08d2d26170e001a6030c1139b5043d89af356a7242e7cc1b0a5c1fdcff0417f7adfd0c
#
# Data & Research
#
# The Best States for Teachers
#
# https://click.message.rentpath.com/?qs=a126a0c983aa9cc9f6539cc4ccba44714c323b19cbe4f8262357180a8c548581f7bfe4d2b0a570a9d6b652cdeca088eb4754976a18694753aa3d394089b9c519
# Read More
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
on GitHub:
# https://github.com/mrinoybanerjee/Wound-Detection/pull/11#event-11915656805
# You are receiving this because you were assigned.
#
# Message ID: <mrinoybanerjee/Wound-Detection/pull/11/issue_event/11915656805@github.com>
#
# Summarized Text:
# Merged # 11 main
# Original Document:
# ### <span aria-hidden="true">✅</span> Deploy Preview for *eclectic-chebakia-d6873a* canceled.
#
#
# |  Name | Link |
# |:-:|------------------------|
# |<span aria-hidden="true">🔨</span> Latest commit | 8ef8232f3b2653c49cdb03313895a565e15cf8c0 |
# |<span aria-hidden="true">🔍</span> Latest deploy log | https://app.netlify.com/sites/eclectic-chebakia-d6873a/deploys/65dc1a07fc175500088a4a16 |
#
# --
# Reply to this email directly or view it on GitHub:
# https://github.com/mrinoybanerjee/Wound-Detection/pull/11#issuecomment-1963318949
# You are receiving this because you were assigned.
#
# Message ID: <mrinoybanerjee/Wound-Detection/pull/11/c1963318949@github.com>
#
# Summarized Text:
# # # # < span aria-hidden= '' true '' > ✅ < /span > Deploy Preview * eclectic-chebakia-d6873a * cancel
# Original Document:
# Assigned #11 to @pallesaisamyukta.
#
# --
# Reply to this email directly or view it on GitHub:
# https://github.com/mrinoybanerjee/Wound-Detection/pull/11#event-11915638468
# You are receiving this because you were assigned.
#
# Message ID: <mrinoybanerjee/Wound-Detection/pull/11/issue_event/11915638468@github.com>
#
# Summarized Text:
# Assigned # 11 @ pallesaisamyukta
# Original Document:
# Added docstrings and comments to setup.py and constants.py for better readability.
# You can view, comment on, or merge this pull request online at:
#
#   https://github.com/mrinoybanerjee/Wound-Detection/pull/11
#
# -- Commit Summary --
#
#   * Added comments and docstrings
#
# -- File Changes --
#
#     M scripts/constants.py (9)
#     M scripts/setup.py (75)
#
# -- Patch Links --
#
# https://github.com/mrinoybanerjee/Wound-Detection/pull/11.patch
# https://github.com/mrinoybanerjee/Wound-Detection/pull/11.diff
#
# --
# Reply to this email directly or view it on GitHub:
# https://github.com/mrinoybanerjee/Wound-Detection/pull/11
# You are receiving this because you were assigned.
#
# Message ID: &lt;mrinoybanerjee/Wound-Detection/pull/11@github.com&gt;
#
#
# Summarized Text:
# Added docstrings comment setup
# Original Document:
# Merged #10 into main.
#
# --
# Reply to this email directly or view it on GitHub:
# https://github.com/mrinoybanerjee/Wound-Detection/pull/10#event-11915569724
# You are receiving this because your review was requested.
#
# Message ID: <mrinoybanerjee/Wound-Detection/pull/10/issue_event/11915569724@github.com>
#
# Summarized Text:
# Merged # 10 main
# Original Document:
# @mrinoybanerjee approved this pull request.
#
# Thank you for the change Abhishek, great due diligence!
#
#
#
# --
# Reply to this email directly or view it on GitHub:
# https://github.com/mrinoybanerjee/Wound-Detection/pull/10#pullrequestreview-1899946261
# You are receiving this because your review was requested.
#
# Message ID: <mrinoybanerjee/Wound-Detection/pull/10/review/1899946261@github.com>
#
# Summarized Text:
# @ mrinoybanerjee approve pull request
# Original Document:
# ### <span aria-hidden="true">✅</span> Deploy Preview for *eclectic-chebakia-d6873a* canceled.
#
#
# |  Name | Link |
# |:-:|------------------------|
# |<span aria-hidden="true">🔨</span> Latest commit | e7e0ec15cb57ebc86ccc435b3fbcae10f3426fab |
# |<span aria-hidden="true">🔍</span> Latest deploy log | https://app.netlify.com/sites/eclectic-chebakia-d6873a/deploys/65dc16b064bccd000867b82f |
#
# --
# Reply to this email directly or view it on GitHub:
# https://github.com/mrinoybanerjee/Wound-Detection/pull/10#issuecomment-1963308101
# You are receiving this because your review was requested.
#
# Message ID: <mrinoybanerjee/Wound-Detection/pull/10/c1963308101@github.com>
#
# Summarized Text:
# # # # < span aria-hidden= '' true '' > ✅ < /span > Deploy Preview * eclectic-chebakia-d6873a * cancel
# Original Document:
# Updated file tree
#
# ```
# .
# ├── 540 Module Project 1.pdf
# ├── README.md
# ├── data
# │   ├── outputs
# │   └── raw
# │       └── WoundDataset.zip
# ├── models
# │   ├── EfficientNet_model_fold_4.pth
# │   ├── Efficientnet_model_fold_4_tfjs
# │   │   ├── group1-shard1of4.bin
# │   │   ├── group1-shard2of4.bin
# │   │   ├── group1-shard3of4.bin
# │   │   ├── group1-shard4of4.bin
# │   │   └── model.json
# │   └── custom_resnet.pth
# ├── notebooks
# │   ├── InceptionV3_Model.ipynb
# │   ├── Model_pth_to_tfjs.ipynb
# │   ├── ResNet50_Model.ipynb
# │   ├── efficient_net.ipynb
# │   ├── non_deep_learning_model.ipynb
# │   └── resNet_34.ipynb
# ├── requirements.txt
# ├── scripts
# │   ├── constants.py
# │   ├── make_dataset.py
# │   ├── model.py
# │   └── setup.py
# └── web-ui
#     ├── package-lock.json
#     ├── package.json
#     ├── public
#     │   ├── favicon.ico
#     │   ├── index.html
#     │   ├── logo192.png
#     │   ├── logo512.png
#     │   ├── manifest.json
#     │   ├── model_files
#     │   │   ├── group1-shard1of4.bin
#     │   │   ├── group1-shard2of4.bin
#     │   │   ├── group1-shard3of4.bin
#     │   │   ├── group1-shard4of4.bin
#     │   │   └── model.json
#     │   └── robots.txt
#     └── src
#         ├── App.css
#         ├── App.js
#         ├── constants.js
#         ├── index.css
#         └── index.js
#
# 12 directories, 39 files
# ```
# You can view, comment on, or merge this pull request online at:
#
#   https://github.com/mrinoybanerjee/Wound-Detection/pull/10
#
# -- Commit Summary --
#
#   * Updated README.md
#
# -- File Changes --
#
#     M README.md (55)
#
# -- Patch Links --
#
# https://github.com/mrinoybanerjee/Wound-Detection/pull/10.patch
# https://github.com/mrinoybanerjee/Wound-Detection/pull/10.diff
#
# --
# Reply to this email directly or view it on GitHub:
# https://github.com/mrinoybanerjee/Wound-Detection/pull/10
# You are receiving this because your review was requested.
#
# Message ID: &lt;mrinoybanerjee/Wound-Detection/pull/10@github.com&gt;
#
#
# Summarized Text:
# Updated file tree `` `
# Original Document:
# @rootsec1 requested your review on: mrinoybanerjee/Wound-Detection#10 [DOCUMENTATION-01] Updated README.md.
#
# --
# Reply to this email directly or view it on GitHub:
# https://github.com/mrinoybanerjee/Wound-Detection/pull/10#event-11915559572
# You are receiving this because your review was requested.
#
# Message ID: <mrinoybanerjee/Wound-Detection/pull/10/issue_event/11915559572@github.com>
#
# Summarized Text:
# @ rootsec1 request review : mrinoybanerjee/Wound-Detection # 10 [ DOCUMENTATION-01 ] Updated README
# Original Document:
# Merged #9 into main.
#
# --
# Reply to this email directly or view it on GitHub:
# https://github.com/mrinoybanerjee/Wound-Detection/pull/9#event-11915534852
# You are receiving this because you were assigned.
#
# Message ID: <mrinoybanerjee/Wound-Detection/pull/9/issue_event/11915534852@github.com>
#
# Summarized Text:
# Merged # 9 main
# Original Document:
# Looks awesome guys! Thank you for the add-ons! This looks good to be shipped.
#
# --
# Reply to this email directly or view it on GitHub:
# https://github.com/mrinoybanerjee/Wound-Detection/pull/9#issuecomment-1963304295
# You are receiving this because you were assigned.
#
# Message ID: <mrinoybanerjee/Wound-Detection/pull/9/c1963304295@github.com>
#
# Summarized Text:
# Looks awesome guy ! Thank add-ons ! look good ship
# Original Document:
# @rootsec1 pushed 1 commit.
#
# 7e96ed966202815ee07d46dbfb2123edd2e93364  Updated presentation
#
# --
# View it on GitHub:
# https://github.com/mrinoybanerjee/Wound-Detection/pull/9/files/7d81a7c2c81661df8338ea52256926711bde26e9..7e96ed966202815ee07d46dbfb2123edd2e93364
# You are receiving this because you are subscribed to this thread.
#
# Message ID: <mrinoybanerjee/Wound-Detection/pull/9/push/17263087239@github.com>
#
#
# Summarized Text:
# @ rootsec1 push 1 commit
# Original Document:
# @rootsec1 approved this pull request.
#
# Added the WoundDataset.zip file in the `data/raw` folder
#
#
#
# --
# Reply to this email directly or view it on GitHub:
# https://github.com/mrinoybanerjee/Wound-Detection/pull/9#pullrequestreview-1899906328
# You are receiving this because you were assigned.
#
# Message ID: <mrinoybanerjee/Wound-Detection/pull/9/review/1899906328@github.com>
#
# Summarized Text:
# @ rootsec1 approve pull request
# Original Document:
# @rootsec1 pushed 1 commit.
#
# 7d81a7c2c81661df8338ea52256926711bde26e9  Preserving WoundDataset.zip
#
# --
# View it on GitHub:
# https://github.com/mrinoybanerjee/Wound-Detection/pull/9/files/cde62f70ec7b1773c94ac501772f72c549709baf..7d81a7c2c81661df8338ea52256926711bde26e9
# You are receiving this because you are subscribed to this thread.
#
# Message ID: <mrinoybanerjee/Wound-Detection/pull/9/push/17262586136@github.com>
#
#
# Summarized Text:
# @ rootsec1 push 1 commit
# Original Document:
# @rootsec1 pushed 1 commit.
#
# cde62f70ec7b1773c94ac501772f72c549709baf  Using EfficientNet in the pipeline
#
# --
# View it on GitHub:
# https://github.com/mrinoybanerjee/Wound-Detection/pull/9/files/6627c46caa630c8c6e8d5955854d23a96ce8953f..cde62f70ec7b1773c94ac501772f72c549709baf
# You are receiving this because you are subscribed to this thread.
#
# Message ID: <mrinoybanerjee/Wound-Detection/pull/9/push/17262562488@github.com>
#
#
# Summarized Text:
# @ rootsec1 push 1 commit
# Original Document:
# @rootsec1 approved this pull request.
#
# This looks good to me.
#
#
#
# --
# Reply to this email directly or view it on GitHub:
# https://github.com/mrinoybanerjee/Wound-Detection/pull/9#pullrequestreview-1899750927
# You are receiving this because you were assigned.
#
# Message ID: <mrinoybanerjee/Wound-Detection/pull/9/review/1899750927@github.com>
#
# Summarized Text:
# @ rootsec1 approve pull request
# Original Document:
# @rootsec1 pushed 1 commit.
#
# 6627c46caa630c8c6e8d5955854d23a96ce8953f  Integrated EfficientNet model in web-ui
#
# --
# View it on GitHub:
# https://github.com/mrinoybanerjee/Wound-Detection/pull/9/files/34f26bf31d6f766b9415d19da44b517cc098ae4a..6627c46caa630c8c6e8d5955854d23a96ce8953f
# You are receiving this because you are subscribed to this thread.
#
# Message ID: <mrinoybanerjee/Wound-Detection/pull/9/push/17259611773@github.com>
#
#
# Summarized Text:
# @ rootsec1 push 1 commit
# Original Document:
# Assigned #9 to @pallesaisamyukta.
#
# --
# Reply to this email directly or view it on GitHub:
# https://github.com/mrinoybanerjee/Wound-Detection/pull/9#event-11913844921
# You are receiving this because you were assigned.
#
# Message ID: <mrinoybanerjee/Wound-Detection/pull/9/issue_event/11913844921@github.com>
#
# Summarized Text:
# Assigned # 9 @ pallesaisamyukta
# Original Document:
# ### <span aria-hidden="true">✅</span> Deploy Preview for *eclectic-chebakia-d6873a* canceled.
#
#
# |  Name | Link |
# |:-:|------------------------|
# |<span aria-hidden="true">🔨</span> Latest commit | 34f26bf31d6f766b9415d19da44b517cc098ae4a |
# |<span aria-hidden="true">🔍</span> Latest deploy log | https://app.netlify.com/sites/eclectic-chebakia-d6873a/deploys/65dba941b7371c0008440749 |
#
# --
# Reply to this email directly or view it on GitHub:
# https://github.com/mrinoybanerjee/Wound-Detection/pull/9#issuecomment-1963058567
# You are receiving this because you were assigned.
#
# Message ID: <mrinoybanerjee/Wound-Detection/pull/9/c1963058567@github.com>
#
# Summarized Text:
# # # # < span aria-hidden= '' true '' > ✅ < /span > Deploy Preview * eclectic-chebakia-d6873a * cancel
# Original Document:
# ( https://elicit.com/ )
#
# Hello! How is your Elicit experience going so far?
#
#
#
# I wanted to tell you about our
# Find Papers ( https://elicit.com/?workflow=table-of-papers ) workflow. It’s the default workflow on our homepage and our most popular workflow:
#
#
#
# Find papers searches over more than 125 million academic papers from the Semantic Scholar database. You can see a sample of journals covered here ( https://www.semanticscholar.org/about/publishers ) (there are over 100,000 in total, I believe). Most academic disciplines are covered.
#
#
#
# In Elicit, you can frame queries in natural language. You can ask questions or write a whole paragraph on what you’re looking for!
#
#
#
# We’ll search over the millions of papers and rank them by relevance to your query. We use semantic search so we’ll find papers even if there’s no keyword overlap.
#
#
#
# You’ll see the first 8 papers, but you can click “Load more” to see more. Find more tips here ( https://support.elicit.com/en/articles/911233 ), or try Find papers now ( https://elicit.com/?workflow=table-of-papers )!
#
#
#
# Let me know if you have any other questions or feedback,
#
#
#
# Juliet
#
# Customer Support at Elicit ( https://elicit.com/ )
#
# Elicit Help Center ( https://support.elicit.com/ )
#
# Elicit Tutorials ( https://www.youtube.com/@elicit-research )
#
# You are receiving this email because you signed up for Elicit ( https://elicit.com/ ), an AI research assistant. You can manage email preferences here ( http://track.customer.io/manage_subscription_preferences/dgTd9ggBAJiydJeydAGN3AN7MX6HDjRdsq01O34= ). To view this email in your browser, click here ( http://track.customer.io/deliveries/dgTd9ggBAJiydJeydAGN3AN7MX6HDjRdsq01O34= ).
#
# Summarized Text:
# ( https : //elicit

# %% [markdown]
# ## Evaluating

# %%
# from rouge import Rouge

# %%
# generated_sum = generated_list[0]
# original_text = email_list[0]

# # Initialize the Rouge object
# rouge = Rouge()

# # Compute ROUGE scores
# scores = rouge.get_scores(generated_sum, original_text)

# # Print ROUGE scores
# print(scores)

# %%
from evaluation import rouge_metric

# %%
average_scores = rouge_metric(email_list, generated_list)

# %%
average_scores
# Out:
# {'rouge-1': {'r': 0.06511441997087261,
#   'p': 0.4279779727764925,
#   'f': 0.10918285025316005},
#  'rouge-2': {'r': 0.01806927564045425,
#   'p': 0.15088988627376695,
#   'f': 0.03097445707538867},
#  'rouge-l': {'r': 0.06511441997087261,
#   'p': 0.4279779727764925,
#   'f': 0.10918285025316005}}
